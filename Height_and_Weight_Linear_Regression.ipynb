# %%
import pandas as pd
data=pd.read_csv('/content/data.csv')
data
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x
# Out:
#     Height
# 0     1.47
# 1     1.50
# 2     1.52
# 3     1.55
# 4     1.57
# 5     1.60
# 6     1.63
# 7     1.65
# 8     1.68
# 9     1.70
# 10    1.73
# 11    1.75
# 12    1.78
# 13    1.80
# 14    1.83

# %%
y
# Out:
# 0     52.21
# 1     53.12
# 2     54.48
# 3     55.84
# 4     57.20
# 5     58.57
# 6     59.93
# 7     61.29
# 8     63.11
# 9     64.47
# 10    66.28
# 11    68.10
# 12    69.92
# 13    72.19
# 14    74.46
# Name: Weight, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=5)

# %%
x_train
# Out:
#     Height
# 14    1.83
# 11    1.75
# 4     1.57
# 8     1.68
# 9     1.70
# 0     1.47
# 12    1.78
# 6     1.63
# 13    1.80
# 3     1.55

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([59.02835631, 52.82487778, 62.13009558, 54.06557349, 67.09287841])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='r')
plt.plot(x_test,y_pred,color='g')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('LINEAR REGRESSION FOR HEIGHT AND WEIGHT DATA')
# Out:
# Text(0.5, 1.0, 'LINEAR REGRESSION FOR HEIGHT AND WEIGHT DATA')

# %%
print('Coefficient :',reg.coef_)
print('Intercept   :',reg.intercept_)
# Out:
# Coefficient : [62.03478533]
# Intercept   : -40.227300219366924
